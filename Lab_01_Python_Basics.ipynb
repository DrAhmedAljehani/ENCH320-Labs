# %% [markdown]
# ## 📝 Important Instructions for Students
#
# ### Step 1: Make Your Own Copy
# When you open this notebook in Google Colab, you will be viewing a **read-only** version. To complete the assignments, you must:
#
# 1. Click **"File" → "Save a copy in Drive"** from the menu
# 2. This creates your personal copy in your Google Drive
# 3. Work on **your copy only** - all your answers will be saved there automatically
#
# ### Step 2: Rename Your Notebook
# After creating your copy, rename it to include your student ID:
#
# 1. Click on the notebook name at the top (currently "Copy of Notebook_01_Python_Basics.ipynb")
# 2. Rename it to: **`Lab_01_Python_Basics_Your.first and last name. ipynb`**
# 3. Example: `Lab_01_Python_Basics_12345678.ipynb`
#
# ### Step 3: Add Your Information
# Create a new markdown cell at the top of your notebook (right after these instructions):
#
# 1. Click **"+ text"** button to create markdown
# 2. Add the following information:
#    ```
#    **Student Name:** Your Full Name
#    **Student ID:** Your Student ID
#    **Date:** Today's Date
#    ```
#
# ### Step 4: Share for Grading
# After completing all tasks, share your notebook with the instructor:
#
# 1. Click the **"Share"** button (top-right corner)
# 2. Enter instructor's email: **[ahmed.a.aljehani@gmail.com]**
# 3. Set permission to **"Editor"**
# 4. Click **"Send"**
#
# **⚠️ Important:** Make sure to share **your copy** from Google Drive, not the original!
#
# ---

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ## 📝 تعليمات مهمة للطلاب
#
# ### الخطوة 1: إنشاء نسخة خاصة بك
# عند فتح هذا الدفتر في Google Colab، ستشاهد نسخة **للقراءة فقط**. لإكمال المهام، يجب عليك:
#
# 1. انقر على **"File" ← "Save a copy in Drive"** من القائمة
# 2. سيتم إنشاء نسخة شخصية في Google Drive الخاص بك
# 3. اعمل على **نسختك فقط** - سيتم حفظ جميع إجاباتك تلقائياً
#
# ### الخطوة 2: إعادة تسمية الدفتر
# بعد إنشاء نسختك، قم بإعادة تسميتها لتتضمن رقم الطالب الخاص بك:
#
# 1. انقر على اسم الدفتر في الأعلى (حالياً "Copy of Notebook_01_Python_Basics.ipynb")
# 2. أعد تسميته إلى: **`Lab_01_Python_Basics_رقم_الطالب.ipynb`**
# 3. مثال: `Lab_01_Python_Basics_12345678.ipynb`
#
# ### الخطوة 3: أضف معلوماتك
# قم بإنشاء خلية markdown جديدة في أعلى الدفتر (مباشرة بعد هذه التعليمات):
#
# 1. انقر على زر **"+ text"** لإنشاء خلية markdown
# 2. أضف المعلومات التالية:
#    ```
#    **اسم الطالب:** الاسم الكامل
#    **رقم الطالب:** رقم الطالب
#    **التاريخ:** تاريخ اليوم
#    ```
#
# ### الخطوة 4: المشاركة للتقييم
# بعد إكمال جميع المهام، شارك دفترك مع المدرس:
#
# 1. انقر على زر **"Share"** (في الزاوية العلوية اليمنى)
# 2. أدخل البريد الإلكتروني للمدرس: **[ahmad.alsaadi@kaust.edu.sa]**
# 3. اضبط الصلاحية على **"Editor"**
# 4. انقر على **"Send"**
#
# **⚠️ مهم:** تأكد من مشاركة **نسختك** من Google Drive، وليس النسخة الأصلية!
#
# ---
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# # Lab 1: Python Basics - Variables, Data Types, and Operators
#
# ## Learning Objectives
# By the end of this lab, you will:
# - Create and use variables to store data
# - Work with different data types (int, float, str, bool)
# - Perform calculations with operators
# - Compare values
# - Write simple, clear Python code
#
# ---
#
# ## 1. Creating Your First Variable
#
# A **variable** is a named container that holds a value. Think of it like a labeled box.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# # معمل كمبيوتر 1: أساسيات Python - المتغيرات وأنواع البيانات والعمليات
#
# ## أهداف التعلم
# بنهاية هذا المختبر، ستتمكن من:
# - إنشاء واستخدام المتغيرات لتخزين البيانات
# - العمل مع أنواع بيانات مختلفة (int، float، str، bool)
# - إجراء حسابات مع العمليات
# - مقارنة القيم
# - كتابة كود بايثون بسيط وواضح
#
# ---
#
# ## 1. إنشاء متغيرك الأول
#
# **المتغير** هو حاوية تحتفظ بقيمة. فكر بها مثل صندوق عليه اسم.
#
# </div>
# </details>

# %% [markdown]
# **What is a variable?**
# ```
# variable_name = value
# ```
# Example: `name = "Alice"` creates a variable called `name` that holds the text "Alice"

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# **ما هو المتغير؟**
# ```python
# variable_name = value
# ```
# مثال: "name = "Alice  ينشئ متغيراً يسمى `name` يحتفظ بالنص "Alice"
#
# </div>
# </details>

# %%
# EXAMPLE: Creating a variable
name = "Alice"
print(name)

# %% [markdown]
# **Task 1.1: Store Your Name**
#
# Create a variable called `student_name` and store your name (e.g., `"John"`). Then print it with:
# ```python
# print("My name is", student_name)
# ```

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# **المهمة 1.1: احفظ اسمك**
#
# أنشئ متغيراً يسمى `student_name` واحفظ فيه اسمك (مثلاً، `"John"`). ثم اطبعه بـ:
# ```
# print("My name is", student_name)
# ```
#
# </div>
# </details>

# %%
# Write your code here for Task 1.1
# Create a variable favorite_color and print it

# %% [markdown]
# ---
#
# ## 2. Working with Numbers - Integers
#
# **Integers** are whole numbers without decimal points: `10`, `100`, `-5`

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ---
#
# ## 2. العمل مع الأرقام - الأعداد الصحيحة
#
# **الأعداد الصحيحة** هي أرقام كاملة بدون فواصل عشرية: `10`, `100`, `-5`
#
# </div>
# </details>

# %%
# EXAMPLE: Integers
age = 20
count = 100
temperature = -5

print("Age:", age)
print("Count:", count)
print("Temperature:", temperature)

# %% [markdown]
# **Task 2.1: Student Information**
#
# Create an integer variable `student_id` with value `12345` and another variable `semester` with value `3`. Print both with:
# ```python
# print("Student ID:", student_id)
# print("Semester:", semester)
# ```

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# **المهمة 2.1: معلومات الطالب**
#
# أنشئ متغير صحيح باسم `student_id` بقيمة `12345` ومتغير آخر باسم `semester` بقيمة `3`. اطبع كليهما بـ:
# ```
# print("Student ID:", student_id)
# print("Semester:", semester)
# ```
#
# </div>
# </details>

# %%
# Write your code here for Task 2.1
# Create students_in_class and year, then print them

# %% [markdown]
# ---
#
# ## 3. Working with Numbers - Floats
#
# **Floats** are decimal numbers: `3.75`, `9.99`, `0.5`

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ---
#
# ## 3. العمل مع الأرقام - الأرقام العشرية
#
# **الأرقام العشرية** هي أرقام لها فواصل عشرية: `3.75`, `9.99`, `0.5`
#
# </div>
# </details>

# %%
# EXAMPLE: Floats
price = 19.99
gpa = 3.85
pi = 3.14159

print("Price:", price)
print("GPA:", gpa)
print("Pi:", pi)

# %% [markdown]
# **Task 3.1: Measurements**
#
# Create a float variable `room_temperature` with value `22.5` (Celsius) and another variable `product_price` with value `49.99`. Print both with:
# ```python
# print("Room temperature:", room_temperature)
# print("Price:", product_price)
# ```

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# **المهمة 3.1: القياسات**
#
# أنشئ متغير عشري باسم `room_temperature` بقيمة `22.5` (بالدرجة المئوية) ومتغير آخر باسم `product_price` بقيمة `49.99`. اطبع كليهما بـ:
# ```
# print("Room temperature:", room_temperature)
# print("Price:", product_price)
# ```
#
# </div>
# </details>

# %%
# Write your code here for Task 3.1
# Create temperature and weight, then print them

# %% [markdown]
# ---
#
# ## 4. Working with Text - Strings
#
# **Strings** are text data, enclosed in quotes: `"hello"`, `'world'`

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ---
#
# ## 4. العمل مع النصوص - السلاسل النصية
#
# **السلاسل النصية** هي البيانات النصية، محاطة بعلامات الاقتباس: `"hello"`, `'world'`
#
# </div>
# </details>

# %%
# EXAMPLE: Strings
first_name = "Alice"
last_name = "Johnson"
city = "Boston"

print("First name:", first_name)
print("Last name:", last_name)
print("City:", city)

# %% [markdown]
# **Task 4.1: Course Information**
#
# Create a string variable `course_name` with value `"Python Programming"` and another variable `instructor` with value `"Dr. Smith"`. Print both with:
# ```python
# print("Course:", course_name)
# print("Instructor:", instructor)
# ```

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# **المهمة 4.1: معلومات المسار**
#
# أنشئ متغير نصي باسم `course_name` بقيمة `"Python Programming"` ومتغير آخر باسم `instructor` بقيمة `"Dr. Smith"`. اطبع كليهما بـ:
# ```
# print("Course:", course_name)
# print("Instructor:", instructor)
# ```
#
# </div>
# </details>

# %%
# Write your code here for Task 4.1
# Create school_name and subject, then print them

# %% [markdown]
# ---
#
# ## 5. True or False - Boolean Values
#
# **Booleans** are values that are either `True` or `False`. Use them for yes/no decisions.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ---
#
# ## 5. صحيح أو خاطئ - القيم المنطقية
#
# **القيم المنطقية** هي قيم إما `True` أو `False`. استخدمها في القرارات نعم/لا.
#
# </div>
# </details>

# %%
# EXAMPLE: Booleans
is_student = True
is_raining = False
is_working = True

print("Is student:", is_student)
print("Is raining:", is_raining)
print("Is working:", is_working)

# %% [markdown]
# **Task 5.1: Student Status**
#
# Create a boolean variable `is_enrolled` with value `True` and another variable `is_graduated` with value `False`. Print both with:
# ```python
# print("Enrolled:", is_enrolled)
# print("Graduated:", is_graduated)
# ```

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# **المهمة 5.1: حالة الطالب**
#
# أنشئ متغير منطقي باسم `is_enrolled` بقيمة `True` ومتغير آخر باسم `is_graduated` بقيمة `False`. اطبع كليهما بـ:
# ```
# print("Enrolled:", is_enrolled)
# print("Graduated:", is_graduated)
# ```
#
# </div>
# </details>

# %%
# Write your code here for Task 5.1
# Create has_laptop and likes_coding, then print them

# %% [markdown]
# ---
#
# ## 6. Changing Variable Values
#
# Variables can be updated. Just assign a new value to change what they hold.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ---
#
# ## 6. تغيير قيم المتغيرات
#
# يمكن تحديث المتغيرات. فقط قم بتعيين قيمة جديدة لتغيير ما تحتفظ به.
#
# </div>
# </details>

# %%
# EXAMPLE: Updating a variable
score = 80
print("First score:", score)

score = 95  # Change the value
print("New score:", score)

# %% [markdown]
# **Task 6.1: Update Test Score**
#
# Create a variable `test_score` with value `75`. Print it. Then update it to `92` and print it again with:
# ```python
# print("Initial score:", test_score)
# test_score = 92
# print("Updated score:", test_score)
# ```

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# **المهمة 6.1: تحديث درجة الاختبار**
#
# أنشئ متغير باسم `test_score` بقيمة `75`. اطبعه. ثم حدثه إلى `92` واطبعه مرة أخرى بـ:
# ```
# print("Initial score:", test_score)
# test_score = 92
# print("Updated score:", test_score)
# ```
#
# </div>
# </details>

# %%
# Write your code here for Task 6.1
# Create count = 10, print it, change to 25, print it again

# %% [markdown]
# ---
#
# ## 7. Good Variable Names
#
# Use lowercase with underscores: `first_name`, `student_age`, `is_active` (NOT `firstName`, `studentAge`, `IsActive`)

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ---
#
# ## 7. أسماء المتغيرات الجيدة
#
# استخدم أحرفاً صغيرة مع شرطات سفلية: `first_name`, `student_age`, `is_active` (ليس `firstName`, `studentAge`, `IsActive`)
#
# </div>
# </details>

# %%
# EXAMPLE: Good variable names
first_name = "Alice"
student_age = 20
is_active = True
school_name = "Boston University"

print(first_name)
print(student_age)
print(is_active)
print(school_name)

# %% [markdown]
# **Task 7.1: Create a Student Profile**
#
# Create 3 variables with good names:
# - `first_name = "Sarah"`
# - `gpa = 3.8`
# - `is_honors_student = True`
#
# Print each one with:
# ```python
# print("Name:", first_name)
# print("GPA:", gpa)
# print("Honors:", is_honors_student)
# ```

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# **المهمة 7.1: إنشاء ملف طالب**
#
# أنشئ 3 متغيرات بأسماء جيدة:
# - `first_name = "Sarah"`
# - `gpa = 3.8`
# - `is_honors_student = True`
#
# اطبع كل واحد بـ:
# ```
# print("Name:", first_name)
# print("GPA:", gpa)
# print("Honors:", is_honors_student)
# ```
#
# </div>
# </details>

# %%
# Write your code here for Task 7.1
# Create 3 variables with good names and print them

# %% [markdown]
# ---
#
# ## 8. Arithmetic Operators
#
# Use operators to perform math: `+`, `-`, `*`, `/`, `**` (power), `//` (integer division), `%` (remainder)

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ---
#
# ## 8. اجراء عمليات حسابية
#
# استخدم المعاملات لإجراء عمليات حسابية: `+`, `-`, `*`, `/`, `**` (قوة)، `//` (قسمة صحيحة)، `%` (الباقي)
#
# </div>
# </details>

# %%
# EXAMPLE: Addition and Subtraction
x = 10
y = 3

sum_result = x + y
difference = x - y

print("Sum:", sum_result)      # 10 + 3 = 13
print("Difference:", difference)  # 10 - 3 = 7

# %% [markdown]
# **Task 8.1: Calculate Total and Difference**
#
# Create `hours_monday = 8` and `hours_tuesday = 6`. Calculate:
# - Total hours: `total_hours = hours_monday + hours_tuesday`
# - Difference: `difference = hours_monday - hours_tuesday`
#
# Print:
# ```python
# print("Total hours:", total_hours)
# print("Difference:", difference)
# ```

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# **المهمة 8.1: احسب الإجمالي والفرق**
#
# أنشئ `hours_monday = 8` و `hours_tuesday = 6`. احسب:
# - إجمالي الساعات: `total_hours = hours_monday + hours_tuesday`
# - الفرق: `difference = hours_monday - hours_tuesday`
#
# اطبع:
# ```
# print("Total hours:", total_hours)
# print("Difference:", difference)
# ```
#
# </div>
# </details>

# %%
# Write your code here for Task 8.1
# Create two numbers, add them, subtract them, print results

# %%
# EXAMPLE: Multiplication and Division
a = 12
b = 4

product = a * b
quotient = a / b

print("Product:", product)    # 12 * 4 = 48
print("Quotient:", quotient) # 12 / 4 = 3.0

# %% [markdown]
# **Task 8.2: Pizza Party Cost**
#
# You're ordering pizzas for a party. Create `price_per_pizza = 15` and `number_of_pizzas = 3`. Calculate:
# - `total_cost = price_per_pizza * number_of_pizzas`
# - `cost_per_person = total_cost / 3`
#
# Print:
# ```python
# print("Total cost:", total_cost)
# print("Cost per person:", cost_per_person)
# ```

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# **المهمة 8.2: حفلة البيتزا**
#
# أنت تطلب البيتزا لحفلة. أنشئ `price_per_pizza = 15` و `number_of_pizzas = 3`. احسب:
# - `total_cost = price_per_pizza * number_of_pizzas`
# - `cost_per_person = total_cost / 3`
#
# اطبع:
# ```
# print("Total cost:", total_cost)
# print("Cost per person:", cost_per_person)
# ```
#
# </div>
# </details>

# %%
# Write your code here for Task 8.2
# Create two numbers, multiply them, divide them, print results

# %%
# EXAMPLE: Power and Remainder
base = 2
exponent = 5
number = 17
divisor = 5

power = base ** exponent
remainder = number % divisor

print("2 to the power of 5:", power)  # 2 ** 5 = 32
print("Remainder of 17 / 5:", remainder)  # 17 % 5 = 2

# %% [markdown]
# **Task 8.3: Battery Power Calculation**
#
# Your phone battery is fully charged with 3 hours of usage remaining. Calculate:
# - `battery_level = 3`
# - How much 2 to the power of battery level: `power_result = 2 ** battery_level`
# - Remaining battery percentage: `remainder = 100 % 15`
#
# Print:
# ```python
# print("2 to the power of", battery_level, "=", power_result)
# print("100 % 15 =", remainder)
# ```

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# **المهمة 8.3: حساب قوة البطارية**
#
# بطارية هاتفك مشحونة بالكامل مع 3 ساعات من الاستخدام المتبقية. احسب:
# - `battery_level = 3`
# - كم يساوي 2 مرفوع لقوة battery level: `power_result = 2 ** battery_level`
# - نسبة البطارية المتبقية: `remainder = 100 % 15`
#
# اطبع:
# ```
# print("2 to the power of", battery_level, "=", power_result)
# print("100 % 15 =", remainder)
# ```
#
# </div>
# </details>

# %%
# Write your code here for Task 8.3
# Calculate a power and a remainder, print results

# %% [markdown]
# ---
#
# ## 9. Comparison Operators
#
# Compare values using: `==` (equal), `!=` (not equal), `>` (greater), `<` (less), `>=` (greater or equal), `<=` (less or equal)
#
# Comparisons return `True` or `False`

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ---
#
# ## 9. عمليات المقارنة
#
# قارن القيم باستخدام: `==` (متساوي)، `!=` (غير متساوي)، `>` (أكبر من)، `<` (أقل من)، `>=` (أكبر أو متساوي)، `<=` (أقل أو متساوي)
#
# المقارنات ترجع `True` أو `False`
#
# </div>
# </details>

# %%
# EXAMPLE: Comparisons
age = 20
limit = 18

print(age > limit)   # Is age greater than 18? True
print(age < limit)   # Is age less than 18? False
print(age == limit)  # Is age equal to 18? False
print(age >= limit)  # Is age greater or equal to 18? True

# %% [markdown]
# **Task 9.1: Compare Test Scores**
#
# Compare two test scores:
# - `midterm_score = 87`
# - `final_score = 92`
#
# Check:
# - Is final score greater than midterm? `final_score > midterm_score`
# - Is midterm lower than final? `midterm_score < final_score`
# - Are they equal? `midterm_score == final_score`
#
# Print:
# ```python
# print("Final > Midterm:", final_score > midterm_score)
# print("Midterm < Final:", midterm_score < final_score)
# print("Scores equal:", midterm_score == final_score)
# ```

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# **المهمة 9.1: مقارنة درجات الاختبار**
#
# قارن درجات اختبار:
# - `midterm_score = 87`
# - `final_score = 92`
#
# تحقق من:
# - هل درجة الامتحان النهائي أكبر من الامتحان الفصلي؟ `final_score > midterm_score`
# - هل درجة الامتحان الفصلي أقل من النهائي؟ `midterm_score < final_score`
# - هل تساوي؟ `midterm_score == final_score`
#
# اطبع:
# ```
# print("Final > Midterm:", final_score > midterm_score)
# print("Midterm < Final:", midterm_score < final_score)
# print("Scores equal:", midterm_score == final_score)
# ```
#
# </div>
# </details>

# %%
# Write your code here for Task 9.1
# Create two numbers and compare them with >, <, ==

# %% [markdown]
# ---
#
# ## 10. Logical Operators
#
# Combine conditions using: `and`, `or`, `not`
# - `and`: Both conditions must be True
# - `or`: At least one condition must be True
# - `not`: Reverses True/False

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ---
#
# ## 10. العمليات المنطقية
#
# اجمع الشروط باستخدام: `and`, `or`, `not`
# - `and`: يجب أن يكون كلا الشرطين صحيحاً
# - `or`: يجب أن يكون أحد الشروط صحيحاً على الأقل
# - `not`: عكس True/False
#
# </div>
# </details>

# %%
# EXAMPLE: and operator
age = 20
has_license = True

can_drive = (age >= 16) and (has_license == True)
print("Can drive:", can_drive)  # True (both conditions are true)

# %% [markdown]
# **Task 10.1: Check Driver License Eligibility**
#
# To get a driver's license, you must be 16 AND have a permit. Check:
# - `driver_age = 16`
# - `has_permit = True`
# - `can_get_license = (driver_age >= 16) and (has_permit == True)`
#
# Print:
# ```python
# print("Can get license:", can_get_license)
# print("Age requirement met:", driver_age >= 16)
# print("Has permit:", has_permit)
# ```

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# **المهمة 10.1: تحقق من أهلية رخصة القيادة**
#
# للحصول على رخصة قيادة، يجب أن تكون 16 سنة وأن تحصل على إذن. تحقق من:
# - `driver_age = 16`
# - `has_permit = True`
# - `can_get_license = (driver_age >= 16) and (has_permit == True)`
#
# اطبع:
# ```
# print("Can get license:", can_get_license)
# print("Age requirement met:", driver_age >= 16)
# print("Has permit:", has_permit)
# ```
#
# </div>
# </details>

# %%
# Write your code here for Task 10.1
# Create score and passed, use and to combine conditions

# %%
# EXAMPLE: or operator
is_weekend = False
is_holiday = True

no_work = is_weekend or is_holiday
print("No work:", no_work)  # True (one condition is true)

# %% [markdown]
# **Task 10.2: Check Free Shipping Eligibility**
#
# You get free shipping if order is over $50 OR you have a coupon. Check:
# - `order_total = 75`
# - `has_coupon = True`
# - `qualifies_for_free_shipping = (order_total >= 50) or (has_coupon == True)`
#
# Print:
# ```python
# print("Qualifies for free shipping:", qualifies_for_free_shipping)
# print("Order over $50:", order_total >= 50)
# print("Has coupon:", has_coupon)
# ```

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# **المهمة 10.2: تحقق من أهلية الشحن المجاني**
#
# تحصل على شحن مجاني إذا كان الطلب أكثر من 50 دولار أو لديك قسيمة. تحقق من:
# - `order_total = 75`
# - `has_coupon = True`
# - `qualifies_for_free_shipping = (order_total >= 50) or (has_coupon == True)`
#
# اطبع:
# ```
# print("Qualifies for free shipping:", qualifies_for_free_shipping)
# print("Order over $50:", order_total >= 50)
# print("Has coupon:", has_coupon)
# ```
#
# </div>
# </details>

# %%
# Write your code here for Task 10.2
# Create is_student and is_senior, use or to combine

# %%
# EXAMPLE: not operator
is_raining = True

is_sunny = not is_raining
print("Is sunny:", is_sunny)  # False (not True = False)

# %% [markdown]
# **Task 10.3: Check Room Availability**
#
# A meeting room is either reserved or available. Check availability using NOT:
# - `room_reserved = True`
# - `room_available = not room_reserved`
#
# Print:
# ```python
# print("Room is reserved:", room_reserved)
# print("Room is available:", room_available)
# print("NOT True =", not True)
# print("NOT False =", not False)
# ```

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# **المهمة 10.3: تحقق من توفر الغرفة**
#
# غرفة الاجتماع إما محجوزة أو متاحة. تحقق من التوفر باستخدام NOT:
# - `room_reserved = True`
# - `room_available = not room_reserved`
#
# اطبع:
# ```
# print("Room is reserved:", room_reserved)
# print("Room is available:", room_available)
# print("NOT True =", not True)
# print("NOT False =", not False)
# ```
#
# </div>
# </details>

# %%
# Write your code here for Task 10.3
# Create is_busy and use not to flip it

# %% [markdown]
# ---
#
# ## 11. Checking Data Types
#
# Use `type()` function to see what type of data a variable holds.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ---
#
# ## 11. التحقق من أنواع البيانات
#
# استخدم دالة `type()` لمعرفة نوع البيانات التي يحتفظ بها المتغير.
#
# </div>
# </details>

# %%
# EXAMPLE: Checking types
name = "Alice"
age = 20
gpa = 3.85
is_student = True

print(type(name))       # <class 'str'>
print(type(age))        # <class 'int'>
print(type(gpa))        # <class 'float'>
print(type(is_student)) # <class 'bool'>

# %% [markdown]
# **Task 11.1: Identify Library Book Data Types**
#
# Create variables for a library book entry:
# - `book_title = "Python Guide"`
# - `total_pages = 350`
# - `avg_rating = 4.5`
# - `is_available = True`
#
# Check each type:
# ```python
# print("Title type:", type(book_title))
# print("Pages type:", type(total_pages))
# print("Rating type:", type(avg_rating))
# print("Available type:", type(is_available))
# ```

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# **المهمة 11.1: تحديد أنواع بيانات كتاب المكتبة**
#
# أنشئ متغيرات لإدخال كتاب بمكتبة:
# - `book_title = "Python Guide"`
# - `total_pages = 350`
# - `avg_rating = 4.5`
# - `is_available = True`
#
# تحقق من كل نوع:
# ```
# print("Title type:", type(book_title))
# print("Pages type:", type(total_pages))
# print("Rating type:", type(avg_rating))
# print("Available type:", type(is_available))
# ```
#
# </div>
# </details>

# %%
# Write your code here for Task 11.1
# Create variables and check their types with type()

# %% [markdown]
# ---
#
# ## 12. Converting Between Data Types
#
# Convert data using: `int()`, `float()`, `str()`, `bool()`

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ---
#
# ## 12. تحويل أنواع البيانات
#
# تحويل البيانات باستخدام: `int()`, `float()`, `str()`, `bool()`
#
# </div>
# </details>

# %%
# EXAMPLE: Converting to int
text_number = "42"
number = int(text_number)

print(text_number, "type:", type(text_number))  # str
print(number, "type:", type(number))           # int

# %% [markdown]
# **Task 12.1: Convert Zip Code to Number**
#
# You have a zip code as a string. Convert it to an integer (Boston zip code: 02134):
# - `zip_code_text = "02134"`
# - `zip_code_number = int(zip_code_text)`
#
# Print:
# ```python
# print("Before conversion:")
# print("  Value:", zip_code_text)
# print("  Type:", type(zip_code_text))
# print("After conversion:")
# print("  Value:", zip_code_number)
# print("  Type:", type(zip_code_number))
# ```

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# **المهمة 12.1: تحويل الرمز البريدي إلى رقم**
#
# لديك رمز بريدي كنصّ. حوله إلى عدد صحيح (رمز بوسطن البريدي: 02134):
# - `zip_code_text = "02134"`
# - `zip_code_number = int(zip_code_text)`
#
# اطبع:
# ```
# print("Before conversion:")
# print("  Value:", zip_code_text)
# print("  Type:", type(zip_code_text))
# print("After conversion:")
# print("  Value:", zip_code_number)
# print("  Type:", type(zip_code_number))
# ```
#
# </div>
# </details>

# %%
# Write your code here for Task 12.1
# Create a string with a number, convert to int, check types

# %%
# EXAMPLE: Converting to string
number = 25
text = str(number)

print(number, "type:", type(number))  # int
print(text, "type:", type(text))      # str

# %% [markdown]
# **Task 12.2: Convert Student Count to Text**
#
# Your class has 28 students (an integer). Convert it to a string and use it in a sentence:
# - `student_count = 28`
# - `student_count_text = str(student_count)`
# - `message = "There are " + student_count_text + " students in class."`
#
# Print:
# ```python
# print("Count type:", type(student_count))
# print("Text type:", type(student_count_text))
# print(message)
# ```

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# **المهمة 12.2: تحويل عدد الطلاب إلى نصّ**
#
# فصلك يضم 28 طالب (عدد صحيح). حوله إلى نصّ واستخدمه في جملة:
# - `student_count = 28`
# - `student_count_text = str(student_count)`
# - `message = "There are " + student_count_text + " students in class."`
#
# اطبع:
# ```
# print("Count type:", type(student_count))
# print("Text type:", type(student_count_text))
# print(message)
# ```
#
# </div>
# </details>

# %%
# Write your code here for Task 12.2
# Create an integer, convert to string, check types

# %% [markdown]
# ---
#
# ## Summary
#
# You have learned:
# - Creating variables for different data types
# - Using operators for arithmetic, comparison, and logic
# - Checking and converting data types
# - Writing clear, readable Python code
#
# **Great work!** You have completed Lab 1 basics.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ---
#
# ## الملخص
#
# لقد تعلمت:
# - إنشاء متغيرات لأنواع بيانات مختلفة
# - استخدام المعاملات للعمليات الحسابية والمقارنة والمنطق
# - التحقق من أنواع البيانات وتحويلها
# - كتابة رمز Python واضح وقابل للقراءة
#
# **عمل رائع!** لقد أكملت أساسيات Lab 1.
#
# </div>
# </details>

# %% [markdown]
# ---
#
# ## Lab 1 Concept Mind Map
#
# [![](https://mermaid.ink/img/pako:eNpNkdFu2zAMRX-FELChzbzUdpw4MdYBXfO4dQVa7GEIMLAWYwuzRYOSk6VB_n1OW9uVXnjES-qKOqqcNalM1cbqGpuNBRBmf3Fxf_AlW_iGzuTu8vKcAPiFYvCpIveKALdC6KmnB88ywB12PYueAJzFv_QnR0fj2YNH8bA3voSKvCcZU2tyuZjGm907_c2OjQYhR7IjDXsW7cbsHYNrMCd35RrKDVaQlyhvgjV6hMdDM3o31vfhtmIcwPnBxhNz9Rr_bEiwe95QfSOd65q8yUcDn-AzTOBqGA7XTTcwx3aUfIUvcH3d83cuTI7VmEarR-B347A8-LvnPQl8hB-s24pHyXlNJhDABxWoQoxWmZeWAlWT1HhGdTyrN8qXVNNGZV2oaYtt5TdqY09dWYP2N3PdVwq3RamyLVauo7bR3WevDRaC9XAqZDXJLbfWqywKFy9NVHZU_1QWR-F0kcbhKpzN4tU8Xi4DdVDZcjZNo2iezNPFfBZGcXoK1PPLteF0Oev2Ik3CeBUlSRKf_gMkoMGR?type=png)](https://mermaid.live/edit#pako:eNpNkdFu2zAMRX-FELChzbzUdpw4MdYBXfO4dQVa7GEIMLAWYwuzRYOSk6VB_n1OW9uVXnjES-qKOqqcNalM1cbqGpuNBRBmf3Fxf_AlW_iGzuTu8vKcAPiFYvCpIveKALdC6KmnB88ywB12PYueAJzFv_QnR0fj2YNH8bA3voSKvCcZU2tyuZjGm907_c2OjQYhR7IjDXsW7cbsHYNrMCd35RrKDVaQlyhvgjV6hMdDM3o31vfhtmIcwPnBxhNz9Rr_bEiwe95QfSOd65q8yUcDn-AzTOBqGA7XTTcwx3aUfIUvcH3d83cuTI7VmEarR-B347A8-LvnPQl8hB-s24pHyXlNJhDABxWoQoxWmZeWAlWT1HhGdTyrN8qXVNNGZV2oaYtt5TdqY09dWYP2N3PdVwq3RamyLVauo7bR3WevDRaC9XAqZDXJLbfWqywKFy9NVHZU_1QWR-F0kcbhKpzN4tU8Xi4DdVDZcjZNo2iezNPFfBZGcXoK1PPLteF0Oev2Ik3CeBUlSRKf_gMkoMGR)
#
# **Key Takeaways:**
# - **Variables** are containers for storing values
# - **Data Types** determine what kind of data can be stored
# - **Operators** allow us to perform operations on data

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ---
#
# ## خريطة مفاهيم Lab 1
#
# **النقاط الرئيسية:**
# - **المتغيرات** هي حاويات لتخزين القيم
# - **أنواع البيانات** تحدد نوع البيانات التي يمكن تخزينها
# - **المعاملات** تسمح لنا بإجراء عمليات على البيانات
#
# </div>
# </details>

# %% [markdown]
# ---
#
# ## Final Review Task - Program a Student Profile
#
# Now it's time to put everything together! Create a complete program that uses all the concepts you've learned.
#
# **Task:** Create a student profile system that:
# 1. Stores student information (name, age, student ID)
# 2. Calculates the student's graduation year (current year + years remaining)
# 3. Checks if they're an honors student (GPA >= 3.5)
# 4. Checks if they can register for advanced courses (sophomore or higher)
# 5. Displays all information with proper types
#
# **Example output should look like:**
# ```
# === STUDENT PROFILE ===
# Name: Alice Johnson
# Age: 20
# Student ID: 98765
# GPA: 3.8
# Expected Graduation Year: 2028
# Is Honors Student: True
# Can Register for Advanced Courses: True
# ```

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ---
#
# ## مهمة المراجعة النهائية - برمجة ملف طالب
#
# الآن حان الوقت لجمع كل شيء معاً! أنشئ برنامجاً كاملاً يستخدم جميع المفاهيم التي تعلمتها.
#
# **المهمة:** أنشئ نظام ملف طالب يقوم بـ:
# 1. تخزين معلومات الطالب (الاسم والعمر ورقم الطالب)
# 2. حساب سنة التخرج للطالب (السنة الحالية + السنوات المتبقية)
# 3. التحقق مما إذا كان الطالب من فئة الشرف (GPA >= 3.5)
# 4. التحقق مما إذا يمكنهم التسجيل في الدورات المتقدمة (sophomore أو أعلى)
# 5. عرض جميع المعلومات بأنواع صحيحة
#
# **يجب أن يبدو الإخراج مثل:**
# ```
# === STUDENT PROFILE ===
# Name: Alice Johnson
# Age: 20
# Student ID: 98765
# GPA: 3.8
# Expected Graduation Year: 2028
# Is Honors Student: True
# Can Register for Advanced Courses: True
# ```
#
# </div>
# </details>

# %%
# Write your complete student profile program here
# Use all the concepts from Lab 1:
# - Variables for different data types
# - Arithmetic operators for calculations
# - Comparison operators for checks
# - Type checking and conversion
# - String concatenation or formatting

# YOUR CODE:

# %% [markdown]
# ---
#
# ## Solution Example
#
# Here's one way to solve the student profile program. Try to solve it yourself first, then check this example.
#
# **Key concepts to use:**
# - Variables: `name`, `age`, `student_id`, `gpa`, `current_year`, `years_remaining`
# - Arithmetic: Calculate `graduation_year = current_year + years_remaining`
# - Comparison: Check `gpa >= 3.5` for honors status
# - Logic: Check `(years_remaining > 1)` for advanced course eligibility
# - Type checking: Use `type()` to verify variable types
# - String concatenation: Combine strings to format output

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ---
#
# ## مثال الحل
#
# إليك طريقة واحدة لحل برنامج ملف الطالب. حاول حلها بنفسك أولاً، ثم تحقق من هذا المثال.
#
# **المفاهيم الرئيسية للاستخدام:**
# - المتغيرات: `name`, `age`, `student_id`, `gpa`, `current_year`, `years_remaining`
# - العمليات الحسابية: احسب `graduation_year = current_year + years_remaining`
# - المقارنة: تحقق من `gpa >= 3.5` لحالة الشرف
# - المنطق: تحقق من `(years_remaining > 1)` لأهلية الدورات المتقدمة
# - التحقق من النوع: استخدم `type()` للتحقق من أنواع المتغيرات
# - سلسلة نصية: اجمع النصوص لتنسيق الإخراج
#
# </div>
# </details>

# %% [markdown]
# **Convert the markdown cell below to code cell to check your solution**

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ---
# حول الخلية ادناه الي خليه كود لتأكد من صحة حلك
#
# </div>
# </details>

# %% [markdown]
# # SOLUTION EXAMPLE: Student Profile Program
# name = "Alice Johnson"
# age = 20
# student_id = 98765
# gpa = 3.8
# current_year = 2026
# years_remaining = 2
#
# # Calculate graduation year (arithmetic)
# graduation_year = current_year + years_remaining
#
# # Check honors status (comparison)
# is_honors_student = gpa >= 3.5
#
# # Check course eligibility (logic + comparison)
# can_register_advanced = years_remaining > 1
#
# # Display results
# print("=== STUDENT PROFILE ===")
# print("Name:", name)
# print("Age:", age)
# print("Student ID:", student_id)
# print("GPA:", gpa)
# print("Expected Graduation Year:", graduation_year)
# print("Is Honors Student:", is_honors_student)
# print("Can Register for Advanced Courses:", can_register_advanced)
#
# # Type verification
# print("\n=== DATA TYPES ===")
# print("Name type:", type(name))
# print("Age type:", type(age))
# print("GPA type:", type(gpa))
# print("Is Honors Student type:", type(is_honors_student))

# %% [markdown]
# ---
#
# ## 🎓 Congratulations!
#
# You have successfully completed **Lab 1: Python Basics**!
#
# ### What You've Mastered:
# ✅ **Variables** - Creating and storing data
# ✅ **Data Types** - Working with integers, floats, strings, and booleans
# ✅ **Operators** - Performing arithmetic, comparisons, and logical operations
# ✅ **Type System** - Checking types and converting between them
# ✅ **Problem Solving** - Combining concepts to solve real-world problems
#
# ### Next Steps:
# Ready to dive deeper? Move on to **Lab 2: Control Flow** where you'll learn:
# - If/Else statements for decision-making
# - Loops for repeating actions
# - Writing more complex programs
#
# **Keep practicing, and happy coding! 🚀**

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ---
#
# ## 🎓 تهانينا!
#
# لقد أكملت بنجاح **Lab 1: أساسيات Python**!
#
# ### ما الذي أتقنته:
# ✅ **المتغيرات** - إنشاء وتخزين البيانات
# ✅ **أنواع البيانات** - العمل مع الأعداد الصحيحة والعشرية والنصوص والقيم المنطقية
# ✅ **المعاملات** - إجراء العمليات الحسابية والمقارنة والمنطقية
# ✅ **نظام الأنواع** - التحقق من الأنواع والتحويل بينها
# ✅ **حل المشاكل** - دمج المفاهيم لحل مشاكل الحياة الحقيقية
#
# ### الخطوات التالية:
# هل أنت مستعد للغوص بشكل أعمق؟ انتقل إلى **Lab 2: Control Flow** حيث ستتعلم:
# - عبارات If/Else لاتخاذ القرارات
# - الحلقات لتكرار الإجراءات
# - كتابة برامج أكثر تعقيداً
#
# **استمر في الممارسة والبرمجة السعيدة! 🚀**
#
# </div>
# </details>
